# %% [markdown]
# <a href="https://colab.research.google.com/github/amadords/Projetos-Publicos/blob/master/Abrindo_Gsheet_no_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Abrindo Gsheet no Colab
# ---
#
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-DanielSousaAmador-purple.svg)](https://www.linkedin.com/in/daniel-sousa-amador)
# [![GitHub](https://img.shields.io/badge/GitHub-amadords-yellow.svg)](https://github.com/amadords)
# [![Medium](https://img.shields.io/badge/Medium-DanielSousaAmador-darkblue.svg)](https://daniel-s-amador.medium.com/)
#
# ![img](https://miro.medium.com/max/1000/1*u7wFZ1U9-ggfFamcB4pHFA.png)
#
#
# Muito provavelmente você já sabe os beneficios que o **G-Suite** tem trazido em suas várias vertentes de atuação. Um exemplo é esse ambiente incrível chamado **Colab**.
#
# Muito provavelmente também já tem utilizado o **Google Sheets** como planilha pessoal ou profissional, então não preciso falar muito sobre ele.
#
# Mas utilizar os dois juntos, será que funciona?
#
# A [**gspread**](https://gspread.readthedocs.io/en/latest/) é a API do **Google** para trabalhar com suas planilhas e é ela que utilizaremos agora para acessar aqui no colab.
#
#
#
#
# Fonte: [Analytics Vidhya](https://medium.com/analytics-vidhya/colab-and-google-sheets-surprisingly-powerful-combination-for-data-science-part-1-bbbb11cbd8e)

# %% [markdown]
# **Instalando a biblioteca gspread**

# %%
# !pip install gspread -q

# %% [markdown]
# **Impotando bibliotecas necessárias**

# %%
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials

# %% [markdown]
# **Autenticação**

# %%
auth.authenticate_user()

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# **Lendo a planilha e convertendo em DataFrame**

# %%
worksheet = gc.open('Planilha_teste').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convertendo em um DataFrame Pandas
import pandas as pd
df = pd.DataFrame.from_records(rows)
# Out:
# [['Id Infosiga', 'Cidade Considerada', 'Região Administrativa', 'Ano Óbito', 'Mês Óbito', 'Mês Descrição', 'Sexo', 'Turno', 'Tipo Acidente', 'SubTipo do Acidente', 'Tipo Veiculo', 'Faixa Etária', 'Idade', 'Tipo Vítima', 'Tipo Local do Acidente', 'Dia Semana', 'Tipo de Via', 'LAT_(geo)', 'LONG_(geo)', 'Rua / Rodovia', 'KM Arredondado', 'Outro Veículo Envolvido', 'Tempo entre Acidente e o Óbito'], ['15219', 'AMERICANA', 'Campinas', '2016', '9', 'SETEMBRO', 'MASCULINO', 'MANHA', 'COLISAO', '', 'MOTOCICLETA', '60-64', '61', 'CONDUTOR', 'PUBLICO', 'SEXTA', 'Vias Municipais', '-22,76716919', '-47,34333028', 'RUA LIMEIRA', 'ND', '', 'Mesmo dia'], ['52351', 'AMERICANA', 'Campinas', '2016', '9', 'SETEMBRO', 'MASCULINO', 'NOITE', 'CHOQUE', 'POSTE', 'MOTOCICLETA', '40-44', '44', 'CONDUTOR', 'PUBLICO', 'DOMINGO', 'Vias Municipais', '-22,750786', '-47,341687', 'AVENIDA BRASIL', '1500', 'NAO DISPONIVEL', 'Mesmo dia'], ['15015', 'AMERICANA', 'Campinas', '2016', '9', 'SETEMBRO', 'MASCULINO', 'MADRUG
# ...

# %% [markdown]
# **Lendo a Base de Dados**

# %%
df.head()
# Out:
#             0   ...                              22
# 0  Id Infosiga  ...  Tempo entre Acidente e o Óbito
# 1        15219  ...                       Mesmo dia
# 2        52351  ...                       Mesmo dia
# 3        15015  ...                       Mesmo dia
# 4        15075  ...                       Mesmo dia
#
# [5 rows x 23 columns]

# %% [markdown]
# **Renomeando as Colunas e Dropando a Linha 0**
#
# Ao carregar os nomes das colunas ficaram na linha 0, logo temos que renomear as colunas e apagar a linha 0.

# %%
df.columns = ['Id Infosiga', 
              'Cidade Considerada',
              'Região Administrativa', 
              'Ano Óbito',
              'Mês Óbito',
              'Mês Descrição', 	
              'Sexo',
              'Turno', 	
              'Tipo Acidente',
              'SubTipo do Acidente',
              'Tipo Veiculo',
              'Faixa Etária',
              'Idade',
              'Tipo Vítima',
              'Tipo Local do Acidente',
              'Dia Semana',
              'Tipo de Via',
              'LAT_(geo)',
              'LONG_(geo)', 	
              'Rua / Rodovia',
              'KM Arredondado', 
              'Outro Veículo Envolvido',
              'Tempo entre Acidente e o Óbito',
              ]

df.drop(0,inplace=True)

# %% [markdown]
# **Visualizando DataFrame após a limpeza**

# %%
df.head()
# Out:
#   Id Infosiga  ... Tempo entre Acidente e o Óbito
# 1       15219  ...                      Mesmo dia
# 2       52351  ...                      Mesmo dia
# 3       15015  ...                      Mesmo dia
# 4       15075  ...                      Mesmo dia
# 5       15310  ...                      Mesmo dia
#
# [5 rows x 23 columns]

# %% [markdown]
# **Visualizando o nome das colunas**

# %%
df.columns
# Out:
# Index(['Id Infosiga', 'Cidade Considerada', 'Região Administrativa',
#        'Ano Óbito', 'Mês Óbito', 'Mês Descrição', 'Sexo', 'Turno',
#        'Tipo Acidente', 'SubTipo do Acidente', 'Tipo Veiculo', 'Faixa Etária',
#        'Idade', 'Tipo Vítima', 'Tipo Local do Acidente', 'Dia Semana',
#        'Tipo de Via', 'LAT_(geo)', 'LONG_(geo)', 'Rua / Rodovia',
#        'KM Arredondado', 'Outro Veículo Envolvido',
#        'Tempo entre Acidente e o Óbito'],
#       dtype='object')

# %% [markdown]
# **Confirmando que é um DataFrame**

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Agora é só fazer as análises!

# %% [markdown]
# # Obrigado!
#
# Obrigado por ter disponibilizado um pouco do seu tempo e atenção aqui. Espero que, de alguma forma, tenha sido útil para seu crescimento. Se houver qualquer dúvida ou sugestão, não hesite em entrar em contato no [LinkedIn](https://www.linkedin.com/in/daniel-sousa-amador) e verificar meus outros projetos no [GitHub](https://github.com/amadords).
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-DanielSousaAmador-purple.svg)](https://www.linkedin.com/in/daniel-sousa-amador)
# [![GitHub](https://img.shields.io/badge/GitHub-amadords-yellow.svg)](https://github.com/amadords)
# [![Medium](https://img.shields.io/badge/Medium-DanielSousaAmador-darkblue.svg)](https://daniel-s-amador.medium.com/)
#
#
#
# <center><img width="90%" src="https://raw.githubusercontent.com/danielamador12/Portfolio/master/github.png"></center>
